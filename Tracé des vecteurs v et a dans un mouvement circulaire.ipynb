# %% [markdown]
# # Tracé de vecteur accélération dans un mouvement circulaire

# %% [markdown]
# <div class = 'alert alert-info'>
# Pour exécuter le code écrit dans un bloc : <b>MAJ-ENTREE </b><br>
#     Pour recommencer depuis le début : Menu <b>Kernel / Restart and clear output </b><br>
#     Toujours exécuter dans l'ordre le code  écrit dans les blocs précédés de la mention <b>Entrée  [  ]</b>
# </div>

# %% [markdown]
# Un pointage du de la centrifugeuse de la cité des étoiles en Russie, dont le bras rotatif a un rayon R = 7,0 m, a permis d'obtenir les coordonnées de position en fonction du temps. Le repère (Oxy) est centré sur le centre de la centrifugeuse.
# ![centrifugeuse02.jpg](attachment:centrifugeuse02.jpg)

# %% [markdown]
# <div class = 'alert alert-warning'>
# QUESTIONS<br>
# 1. Compléter ci-dessous les 5 lignes manquantes du programme ci-dessous puis exécuter le programme pour faire apparaître la figure donnantla trajectoire et les vecteurs vitesse et accélération.<br>
# 2. (sur la copie) Justifier les deux bornes de la boucles "for...in.."permettant de calculer les coordonnées du vecteur vitesse.<br>
# 3. (sur la copie) Idem pour la boucle permettant de calculer les coordonnées du vecteur accélération.<br>
# 4. (sur la copie) D'après la figure, sur quelle portion de trajectoire (entre G0 et G20) a-t-on un mouvement circulaire uniforme ? Justifier à partir des tracés des vecteurs v et a.<br>
# 5. (sur la copie) Sur la partie circulaire uniforme, estimer la norme de la vitesse avec l'échelle donnée. En déduire la valeur théorique de la norme de l'accélération. Est-ce cohérent avec la valeur d'accélération trouvée avec l'échelle de la figure ?<br>
#     </div>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# listes de valeurs des grandeurs x, y et t #

t = [0,0.2,0.4,0.6,0.8,1,1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2,3.4,3.6,3.8]
x = [7,6.998881099,6.982104744,6.90956205,6.715502101,6.312235615,5.599248567,4.480957653,2.89565726,0.855470396,-1.508498917,-3.91012293,-5.905091302,-6.949767109,-6.574937759,-4.753602016,-1.884093372,1.400859311,4.376921437,6.38786902] 
y =[0,0.125153331,0.500213304,1.121584717,1.975356052,3.025835677,4.201001724,5.37782656,6.373003141,6.947529806,6.835527121,5.806112182,3.758975487,0.83710043,-2.402122699,-5.138411026,-6.741675768,-6.858395818,-5.462834313,-2.86271364]
  
dt =         #  A COMPLETER on définit la durée entre 2 images
n=len(x)     # le fonction len(x) renvoie le nombre de valeurs de la liste de x

vx=[None]    # on crée une liste vx dont la 1ère valeur sera vide
vy=[None]    # on crée une liste vy dont la 1ère valeur sera vide
for i in range(1,n-1) :
    vx.append(     )          #  A COMPLETER on rentre dans la liste la valeur vx de la i-ème position calculée avec la moyenne centrée (point d'avant- point d'après)
    vy.append(     )          #  A COMPLETER idem pour vy
    v = plt.quiver(x[i], y[i], vx[i], vy[i], units = "dots", color = "red", scale = 0.2) # tracé du vecteur vitesse en précisant son origine et ses coordonnées
    
ax=[None,None]   # on crée une liste ax dont les 2 premières valeurs seront vides
ay=[None,None]   # on crée une liste ax dont les 2 premières valeurs seront vides
for i in range(2,n-2) :
    ax.append(   )   #  A COMPLETER on rentre dans la liste la valeur ax de la i-ème position
    ay.append(    )  #  A COMPLETER idem pour ay
    a = plt.quiver(x[i], y[i], ax[i], ay[i], units = "dots", color = "blue", scale = 0.4) # tracé du vecteur accélération
    
plt.quiverkey(v, 0.9, 0.92, 10, label=r"$10\ \mathrm{m \cdot s^{-1}}$", coordinates = "axes") # indique l'échelle du vecteur v
plt.quiverkey(a, 0.9, 0.85, 20, label=r"$20\ \mathrm{m \cdot s^{-2}}$", coordinates = "axes") # indique l'échelle du vecteur a
fig = plt.figure(1)
fig.set_figheight(10) # fixe la hauteur du graphe
fig.set_figwidth(10) # fixe la largeur du graphe
plt.axis('equal') # impose des axes orthonormés
plt.plot(x,y ,"ro")      # on donne les grandeurs à mettre sur les axes   
plt.xlabel(" abscisse x du point en m   ")   
plt.ylabel(" ordonnée y du point en m  ")   
plt.title('Positions, vitesse et accélération de la cabine')
plt.scatter(0, 0, marker = "+", color = "black")   # place un point au centre de la figure pour indiquer le centre du cercle
for i in range(0,n):
    plt.plot([0,x[i]],[0,y[i]],'k--',lw=0.2)    # permet de tracer le vecteur position (rayon du cercle) à chaque date
plt.show ()          # fait afficher le graphe #

# %%
# %history
